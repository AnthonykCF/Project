# %%
class Character:
    def __init__(self, name, hp, level, char_class, spell_slots=None):
        self.name = name
        self.hp = hp
        self.level = level
        self.char_class = char_class
        self.spell_slots = spell_slots if spell_slots else 0

    def attack(self):
        print(f"{self.name} attacks!")

    def cast_spell(self):
        if self.char_class == "Mage":
            if self.spell_slots > 0:
                print(f"{self.name} casts a spell!")
                self.spell_slots -= 1
            else:
                print(f"{self.name} is out of spell slots!")
        else:
            print(f"{self.name} can't cast spells!")

    def add_item(self, item):
        self.inventory.append(item)
        
    def remove_item(self, item):
        self.inventory.remove(item)
        
    def display_inventory(self):
        print(f"{self.name}'s Inventory:")
        for item in self.inventory:
            print(f"{item['name']} - {item['description']}")
            
    def get_item_details(self, item_name):
        for item in self.inventory:
            if item['name'] == item_name:
                print(f"Name: {item['name']}")
                print(f"Description: {item['description']}")
                print(f"Trait: {item['trait']}")
                if 'bonus' in item:
                    print(f"Bonus: {item['bonus']}")
                break
        else:
            print(f"{item_name} not found in inventory.")
            
    def equip_item(self):
        item_name = input("Enter the name of the item you want to equip: ")
        for item in self.inventory:
            if item['name'] == item_name:
                print(f"{self.name} equipped {item['name']}.")
                self.remove_item(item)
                break
        else:
            print(f"{item_name} not found in inventory.")
            
    def unequip_item(self):
        item_name = input("Enter the name of the item you want to unequip: ")
        for item in self.inventory:
            if item['name'] == item_name:
                print(f"{self.name} unequipped {item['name']}.")
                self.add_item(item)
                break
        else:
            print(f"{item_name} not found in inventory.")
            
# Example inventory items
knife = {
    "name": "Knife",
    "description": "Forged in the depths of Polymar.",
    "trait": "Edged weapon, one-handed",
    "bonus": {"magic": 5},
}

staff = {
    "name": "Staff",
    "description": "A gnarled wooden staff.",
    "trait": "Two-handed weapon, magic amplifier",
    "bonus": {"magic": 10},
}

potion = {
    "name": "Potion",
    "description": "A small vial of glowing blue liquid.",
    "trait": "Healing potion",
    "bonus": {"health": 20},
}
#Test
name = input("Enter your player name: ")
char_class = input("Enter your player type (Warrior/Mage/Rogue): ")


Character = Character(name, char_class,level, char_class)
Character.add_item(knife)
Character.add_item(staff)
Character.add_item(potion)
Character.display_inventory()
action = input("Do you want to equip or unequip an item? (equip/unequip/no): ")

while action != "no":
    if action == "equip":
        Character.equip_item()
    elif action == "unequip":
        Character.unequip_item()
    else:
        print("Invalid action.")
    action = input("Do you want to equip or unequip an item? (equip/unequip/no): ")
Character.display_inventory()
# Out:
# Enter your player name:  Ant
# Enter your player type (Warrior/Mage/Rogue):  Mage
# Do you want to equip or unequip an item? (equip/unequip/no):  equip
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 100
#      98 while action != "no":
#      99     if action == "equip":
# --> 100         Character.equip_item()
#     101     elif action == "unequip":
#     102         Character.unequip_item()
#
# TypeError: Character.equip_item() missing 1 required positional argument: 'self'

# %%
Character.display_inventory()
# Out:
# bill's Inventory:
# Staff - A gnarled wooden staff.
# Potion - A small vial of glowing blue liquid.

# %%
Character.inventory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 Character.inventory
#
# NameError: name 'Character' is not defined

# %%
player.inventory.remove(staff)

# %%
class Skill_Tree(Character):
    def __init__(self, name, hp, level, char_class, skill_points):
        super().__init__(name, hp, level, char_class)
        self.skill_points = skill_points
    
    def select_class(self, char_class):
        self.char_class = char_class
        print(f"{self.name} selects {char_class} class.")

    def show_skill_tree(self):
        print(f"{self.char_class} Skill Tree:")
        # Implement logic to show the skill tree based on the character's class
        if self.char_class == "Warrior":
            print("1. Sword Mastery")
            print("2. Shield Bash")
            print("3. Warcry")
        elif self.char_class == "Mage":
            print("1. Fireball")
            print("2. Ice Blast")
            print("3. Teleport")
        elif self.char_class == "Rogue":
            print("1. Stealth")
            print("2. Backstab")
            print("3. Poison Strike")
        else:
            print("No skill tree available for this class.")
     def learn_new_skill(self, skill_name):
        if self.skill_points > 0:
            self.skills.append(skill_name)
            self.skill_points -= 1
            print(f"{self.name} learns {skill_name}!")
        else:
            print(f"{self.name} doesn't have enough skill points to learn {skill_name}.")

     def reset(self):
        self.hp = 100
        self.level = 1
        self.skill_points = 0
        self.skills = []
        print(f"{self.name}'s attributes have been reset.")

# %%
#List of Classes
class Warrior(Character):
    def __init__(self, name, hp, level):
        super().__init__(name, hp, level, "Warrior")

    def attack(self):
        print(f"{self.name} swings a mighty sword!")


class Mage(Character):
    def __init__(self, name, hp, level, spell_slots):
        super().__init__(name, hp, level, "Mage", spell_slots)

    def attack(self):
        print(f"{self.name} launches a magic missile!")


class Rogue(Character):
    def __init__(self, name, hp, level):
        super().__init__(name, hp, level, "Rogue")

    def attack(self):
        print(f"{self.name} strikes from the shadows with a dagger!")
        
#Diffrent characters name and stats
        warrior = Warrior("Karlach", 100, 1) # (Hp,Level)
        mage = Mage("Gale", 80, 12, 1)
        rogue = Rogue("Astarion", 90, 1)

# %%
class Player(Character):
    def __init__(self, name, hp, level, char_class, exp=0, position=(0, 0)):
        super().__init__(name, hp, level, char_class)
        self.exp = exp
        self.position = position

    def gain_exp(self, amount):
        self.exp += amount
        print(f"{self.name} gains {amount} EXP!")

    def move(self, direction):
        x, y = self.position
        if direction == 'up':
            y += 1
        elif direction == 'down':
            y -= 1
        elif direction == 'left':
            x -= 1
        elif direction == 'right':
            x += 1
        else:
            print("Invalid direction.")
            return
        self.position = (x, y)
        print(f"{self.name} moves to position ({x}, {y})!")

def level_up(self):
        self.level += 1
        self.exp -= 50
        self.skill_points += 1
        print(f"{self.name} levels up to level {self.level}! Gained 1 skill point.")
